# %% [markdown]
# <h1>AirAccidents</h1>
#
# ## Introdução
#
# O transporte aéreo desempenha um papel vital no desenvolvimento econômico e social de um país, proporcionando conectividade rápida e eficiente entre diferentes regiões. No entanto, como em qualquer modalidade de transporte, acidentes aéreos podem ocorrer, colocando em risco a vida dos passageiros e tripulantes, além de gerar impactos significativos na indústria e na segurança do setor.
#
# ## Base de dados
#
# Arquivo: Segurança Operacional - Ocorrências Aeronáuticas - Formato CSV
#
# Base de dados das ocorrências aeronáuticas enviadas pela Força Aérea Brasileira por meio do CENIPA para a ANAC acrescido de informações enriquecidas pela ANAC.
#
# [Clique aqui para acessar a base de dados](https://dados.gov.br/dados/conjuntos-dados/ocorrncias-aeronuticas)

# %%
import pandas as pd
import numpy as np
import dash

# %%
df = pd.read_csv('base.csv', delimiter=";")
df = df.drop(columns = ['Numero_da_Ocorrencia', 'Numero_da_Ficha', 'Hora_da_Ocorrencia', 'ICAO', 'Tipo_de_Aerodromo', 'Aerodromo_de_Destino', 'Aerodromo_de_Origem','CLS', 'Tipo_ICAO', 'PMD', 'PSSO'])
df['Data_da_Ocorrencia'] = df['Data_da_Ocorrencia'].apply(lambda x:'0' if x.split('/')[2] != '2022' else x)
df = df[df['Data_da_Ocorrencia'] != '0']
print(df)
# Out:
#                           Operador_Padronizado Classificacao_da_Ocorrencia  \
# 9882   AEREO AGRICOLA SANTA MARIA - LTDA - EPP                    Acidente
# 9883   AEREO AGRICOLA SANTA MARIA - LTDA - EPP                    Acidente
# 9884                      ADRIANA DIAS RIBEIRO             Incidente Grave
# 9885       AZUL LINHAS AÉREAS BRASILEIRAS S.A.                   Incidente
# 9886             A. R. T. TAXI AEREO LTDA - ME                   Incidente
# ...                                        ...                         ...
# 11765           FERNANDO HORTA DA CUNHA JUNIOR                   Incidente
# 11766                                      GOL                   Incidente
# 11767               MARTINEZ RIDAO AVIACION SL                   Incidente
# 11768                                     AZUL                   Incidente
# 11769             MASTER AVIAÇÃO AGRÍCOLA LTDA                    Acidente
#
#       Data_da_Ocorrencia   Municipio  UF        Regiao  \
# 9882          18/04/2022  CABECEIRAS  GO  Centro-Oeste
# 9883          18/04/2022  CABECEIRAS  GO  Centro-Oeste
# 9884          10/04/2022   PARANAVAÍ  PR           Sul
# 9885          09/04/2022      MANAUS  AM         Norte
# 9886          09/12/2022  RIO BRANCO  AC         Norte
# ...                  ...         ...  ..           ...
# 11765         07/10/2022     UBERABA  MG       Sudeste
# 11766         02/02/2022     GOIÂNIA  GO  Centro-Oeste
# 11767         05/11/2022    GUANAMBI  BA      Nordeste
# 11768         13/10/2022    CAMPINAS  SP       Sudeste
# 11769         08/12/2022         NaN  MT  Centro-Oeste
#
#                                        Descricao_do_Tipo  Latitude Longitude  \
# 9882                            PERDA DE CONTROLE EM VOO  -15,5953  -47,0957
# 9883                           OPERAÇÃO A BAIXA ALTITUDE  -15,5953  -47,0957
# 9884   FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...  -23,0903  -52,4886
# 9885   FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...  -3,04111  -60,0506
# 9886   FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...   -9,5206  -67,5353
# ...                                                  ...       ...       ...
# 11765  FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...       NaN       NaN
# 11766                        CONTATO ANORMAL COM A PISTA       NaN       NaN
# 11767                FALHA OU MAU FUNCIONAMENTO DO MOTOR  -14,1229  -42,4446
# 11768  FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...  -23,0025  -47,0804
# 11769                                      INDETERMINADO       NaN       NaN
#
#                                                Historico  ...  \
# 9882   A aeronave decolou da área de pouso para uso a...  ...
# 9883   A aeronave decolou da área de pouso para uso a...  ...
# 9884   A aeronave decolou do Aeródromo Tatuí (SDTF), ...  ...
# 9885   A aeronave decolou do Aeródromo de Viracopos (...  ...
# 9886   A aeronave se encontrava no Aeroporto Plácido ...  ...
# ...                                                  ...  ...
# 11765  A aeronave decolou do Aeroporto Tenente Corone...  ...
# 11766  A aeronave decolou do aeródromo Santa Genoveva...  ...
# 11767  A aeronave decolou do Aeródromo Guararapes – G...  ...
# 11768  A aeronave decolou do aeródromo de Viracopos (...  ...
# 11769  A aeronave decolou da pista da Fazenda Castanh...  ...
#
#       Lesoes_Leves_Passageiros Lesoes_Leves_Terceiros Ilesos_Tripulantes  \
# 9882                       NaN                    NaN                NaN
# 9883                       NaN                    NaN                NaN
# 9884                       NaN                    NaN                2.0
# 9885                       NaN                    NaN                4.0
# 9886                       NaN                    NaN                2.0
# ...                        ...                    ...                ...
# 11765                      NaN                    NaN                1.0
# 11766                      NaN                    NaN                5.0
# 11767                      NaN                    NaN                1.0
# 11768                      NaN                    NaN                4.0
# 11769                      NaN                    NaN                NaN
#
#       Ilesos_Passageiros Lesoes_Desconhecidas_Tripulantes  \
# 9882                 NaN                              NaN
# 9883                 NaN                              NaN
# 9884                 NaN                              NaN
# 9885                 NaN                              NaN
# 9886                 9.0                              NaN
# ...                  ...                              ...
# 11765                5.0                              NaN
# 11766              144.0                              NaN
# 11767                NaN                              NaN
# 11768               59.0                              NaN
# 11769                NaN                              1.0
#
#       Lesoes_Desconhecidas_Passageiros Lesoes_Desconhecidas_Terceiros  \
# 9882                               NaN                            NaN
# 9883                               NaN                            NaN
# 9884                               NaN                            NaN
# 9885                               NaN                            NaN
# 9886                               NaN                            NaN
# ...                                ...                            ...
# 11765                              NaN                            NaN
# 11766                              NaN                            NaN
# 11767                              NaN                            NaN
# 11768                              NaN                            NaN
# 11769                              NaN                            NaN
#
#                Modelo  Numero_de_Assentos       Nome_do_Fabricante
# 9882        PA-25-235                 1.0           PIPER AIRCRAFT
# 9883        PA-25-235                 1.0           PIPER AIRCRAFT
# 9884         EMB-810C                 6.0                  EMBRAER
# 9885   ERJ 190-200 LR               125.0                  EMBRAER
# 9886             208B                11.0          CESSNA AIRCRAFT
# ...               ...                 ...                      ...
# 11765            210N                 6.0          CESSNA AIRCRAFT
# 11766         737-8EH               196.0           BOEING COMPANY
# 11767             NaN                 NaN                      NaN
# 11768     ATR-72-212A                76.0  AEROSPATIALE AND ALENIA
# 11769           A188B                 1.0          CESSNA AIRCRAFT
#
# [822 rows x 34 columns]
